# %% [markdown]
# # PyTorch Neural Networks
# Nun, dass wir Tensoren eingeführt haben, verschiedenste Operationen auf Tensoren gesehen haben und noch einige weitere Spielereien bereits kennen, ist es Zeit, neuronale Netze in PyTorch zu implementieren.
# Dafür werden wir sehr häufig auf das Modul `torch.nn` zurückgreifen. Hier können wir auf die unterschiedlichsten Klassen, Methoden, usw. zugreifen.

# %%
import torch
from torch import nn #für schnelleres Schreiben, reine Deko!

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork()
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# saving and loading models!
